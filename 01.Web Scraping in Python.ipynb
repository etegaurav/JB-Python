# %% [markdown]
# # Web Scraping of information out of webpages built in HTML
#
# ## important libraries/modules to be imported
#    #### 1. pandas

# %%
import pandas as pd

# %% [markdown]
# ### Using the read_html function, all the tabular data content
# ### can be read and then stored in list
#
# #### Extracting the cities information from the below wikipedia page and storing the information in a list

# %%
imdb_data = pd.read_html('https://en.wikipedia.org/wiki/List_of_cities_in_the_United_Kingdom')

# %% [markdown]
# ### checking the type of the variable

# %%
type(imdb_data)
# Out:
# list

# %% [markdown]
# ## Checking the length of the list

# %%
len(imdb_data)
# Out:
# 4

# %% [markdown]
# ## Exploring each element of the list

# %%
# exploring the first element stored in the list and comparing it with the webpage.
imdb_data[0]
# Out:
#     0                                                  1
# 0 NaN  It has been suggested that List of smallest ci...

# %% [markdown]
# ![1st%20element%20from%20the%20page.JPG](attachment:1st%20element%20from%20the%20page.JPG)

# %%
# exploring the second element stored in the list and comparing it with the webpage.
imdb_data[1]
# Out:
#                                               City[1]  \
# 0   Aberdeen32(Scots: Aiberdeen)(Scottish Gaelic: ...
# 1   Armagh11(Irish: Ard Mhacha)(Ulster-Scots: Airm...
# 2                                             Bangor1
# 3                                               Bath1
# 4   Belfast(Irish: Béal Feirste)(Ulster-Scots: Bil...
# ..                                                ...
# 64                                      Westminster21
# 65                                        Winchester1
# 66                                    Wolverhampton16
# 67                                         Worcester3
# 68                                             York18
#
#    Year grantedor confirmed  \
# 0           31(Burgh: 1179)
# 1                       NaN
# 2           time immemorial
# 3                       NaN
# 4                       NaN
# ..                      ...
# 64                      NaN
# 65          time immemorial
# 66                      NaN
# ...

# %% [markdown]
# ## The element in the list displays the table as present in the webpage
#
# ![2nd%20element%20from%20the%20page.JPG](attachment:2nd%20element%20from%20the%20page.JPG)
